# %%
import pandas as pd
import os
import glob
import re

# %%
data_dir = "output"
csv_files_name = "naver_stock_articles_*.csv"
numeric_columns = ['article_viewers', 'article_likes', 'article_dislikes']
cleaned_data_dir = 'cleaned_output'
df_list = []
before_data_row = 0
after_data_row = 0

if not os.path.exists(data_dir):
    os.makedirs(data_dir)
    print(f"'{data_dir}' 폴더를 생성했습니다. 분석할 CSV 파일들을 이 폴더에 넣어주세요.")
    
if not os.path.exists(cleaned_data_dir):
    os.makedirs(cleaned_data_dir)
    print(f"'{cleaned_data_dir}' 폴더를 생성했습니다. 중복 제거 및 기본 전처리 데이터가 저장됩니다.")
    
def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = re.sub(r'[\r\n\t]+', ' ', text) # 줄바꿈, 탭을 공백으로
    text = text.strip() # 양 끝 공백 제거
    return text

# %%
# output 폴더에서 csv_files_name과 일치하는 모든 csv 파일을 찾아서 리스트 형태로 저장
csv_files = glob.glob(os.path.join(data_dir, csv_files_name))

if not csv_files:
    print(f"'{data_dir}' 폴더에 CSV 파일이 없습니다. 코드를 실행하기 전에 파일을 추가해주세요.")
else:
    # 모든 CSV 파일을 읽어 리스트에 담습니다. stock_code의 값이 변경 되는 것을 방지하기위해 명시적으로 stock_code는 문자열로 가져오라고 알려줍니다.
    print(f"중복 제거 할 총 파일 갯수 : {len(csv_files)}")
    for file in csv_files :
        df = pd.read_csv(file, dtype={'stock_code': str})
        print(f"중복 제거 전 {file}의 레코드 수 : {len(df)}")
        before_data_row += len(df)
        df = df.drop_duplicates(subset=["article_url"], keep="first")
        print(f"중복 제거 후 {file}의 레코드 수 : {len(df)}")
        after_data_row += len(df)
        df['stock_code'] = df['stock_code'].astype(str).str.zfill(6)
        for col in numeric_columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df['article_comments'] = df['article_comments'].fillna('')
        df['article_comments'] = df['article_comments'].apply(clean_text)
        df['article_comments'] = df['article_comments'].apply(lambda x: [comment.strip() for comment in x.split('||')] if x else [])
        df['article_content'] = df['article_content'].apply(clean_text)
        df.reset_index(drop=True, inplace=True)
        df_list.append(df)
        output_file_base = file.replace(data_dir, cleaned_data_dir).replace(".csv", "")
        df.to_csv(output_file_base+'_cleaned.csv', index=False, encoding='utf-8-sig')
        df.to_json(output_file_base+'_cleaned.json', indent=4, force_ascii=False)
        print(f"전처리된 데이터가 csv, json 포멧으로 저장되었습니다.")
    df_all = pd.concat(df_list, ignore_index=True)
    df_all.to_csv(os.path.join(cleaned_data_dir, 'all_naver_stock_articles_cleaned.csv'), index=False, encoding='utf-8-sig')
    df_all.to_json(os.path.join(cleaned_data_dir, 'all_naver_stock_articles_cleaned.json'), indent=4, force_ascii=False)
    print("\n")
    print("-"*50)
    print(f"전처리된 모든 데이터가 {cleaned_data_dir} 폴더에 파일 csv, json로 저장되었습니다.")
    print(f"중복제거 전 전체 데이터 레코드 수 : {before_data_row}")
    print(f"중복제거 후 전체 데이터 레코드 수 : {after_data_row}")
    print(f"전체 데이터의 레코드 수 : {len(df_all)}")
# Out:
# 중복 제거 할 총 파일 갯수 : 64
# 중복 제거 전 output/naver_stock_articles_20대_안철수_004770.csv의 레코드 수 : 720761
# 중복 제거 후 output/naver_stock_articles_20대_안철수_004770.csv의 레코드 수 : 5354
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_안철수_013700.csv의 레코드 수 : 131092
# 중복 제거 후 output/naver_stock_articles_20대_안철수_013700.csv의 레코드 수 : 2272
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_안철수_026910.csv의 레코드 수 : 186
# 중복 제거 후 output/naver_stock_articles_20대_안철수_026910.csv의 레코드 수 : 62
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_안철수_049480.csv의 레코드 수 : 14816
# 중복 제거 후 output/naver_stock_articles_20대_안철수_049480.csv의 레코드 수 : 756
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_안철수_053800.csv의 레코드 수 : 12090096
# 중복 제거 후 output/naver_stock_articles_20대_안철수_053800.csv의 레코드 수 : 21977
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_윤석열_004830.csv의 레코드 수 : 1819006
# 중복 제거 후 output/naver_stock_articles_20대_윤석열_004830.csv의 레코드 수 : 8506
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_윤석열_007860.csv의 레코드 수 : 109182
# 중복 제거 후 output/naver_stock_articles_20대_윤석열_007860.csv의 레코드 수 : 2062
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_윤석열_016880.csv의 레코드 수 : 18043
# 중복 제거 후 output/naver_stock_articles_20대_윤석열_016880.csv의 레코드 수 : 823
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_윤석열_019770.csv의 레코드 수 : 4986
# 중복 제거 후 output/naver_stock_articles_20대_윤석열_019770.csv의 레코드 수 : 429
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_윤석열_034020.csv의 레코드 수 : 26997
# 중복 제거 후 output/naver_stock_articles_20대_윤석열_034020.csv의 레코드 수 : 26997
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_윤석열_052690.csv의 레코드 수 : 499743
# 중복 제거 후 output/naver_stock_articles_20대_윤석열_052690.csv의 레코드 수 : 4460
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_윤석열_053290.csv의 레코드 수 : 2698795
# 중복 제거 후 output/naver_stock_articles_20대_윤석열_053290.csv의 레코드 수 : 10375
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_004310.csv의 레코드 수 : 287
# 중복 제거 후 output/naver_stock_articles_20대_이재명_004310.csv의 레코드 수 : 87
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_009830.csv의 레코드 수 : 49699
# 중복 제거 후 output/naver_stock_articles_20대_이재명_009830.csv의 레코드 수 : 1399
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_010620.csv의 레코드 수 : 5751
# 중복 제거 후 output/naver_stock_articles_20대_이재명_010620.csv의 레코드 수 : 461
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_015020.csv의 레코드 수 : 21602
# 중복 제거 후 output/naver_stock_articles_20대_이재명_015020.csv의 레코드 수 : 902
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_016920.csv의 레코드 수 : 18920
# 중복 제거 후 output/naver_stock_articles_20대_이재명_016920.csv의 레코드 수 : 860
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_025950.csv의 레코드 수 : 97013
# 중복 제거 후 output/naver_stock_articles_20대_이재명_025950.csv의 레코드 수 : 1953
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_042940.csv의 레코드 수 : 404
# 중복 제거 후 output/naver_stock_articles_20대_이재명_042940.csv의 레코드 수 : 104
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_045340.csv의 레코드 수 : 3965
# 중복 제거 후 output/naver_stock_articles_20대_이재명_045340.csv의 레코드 수 : 374
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_045660.csv의 레코드 수 : 786788
# 중복 제거 후 output/naver_stock_articles_20대_이재명_045660.csv의 레코드 수 : 5588
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_052400.csv의 레코드 수 : 24492
# 중복 제거 후 output/naver_stock_articles_20대_이재명_052400.csv의 레코드 수 : 972
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_065770.csv의 레코드 수 : 173
# 중복 제거 후 output/naver_stock_articles_20대_이재명_065770.csv의 레코드 수 : 68
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_067290.csv의 레코드 수 : 1809
# 중복 제거 후 output/naver_stock_articles_20대_이재명_067290.csv의 레코드 수 : 249
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_224110.csv의 레코드 수 : 21287
# 중복 제거 후 output/naver_stock_articles_20대_이재명_224110.csv의 레코드 수 : 902
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_317240.csv의 레코드 수 : 85556
# 중복 제거 후 output/naver_stock_articles_20대_이재명_317240.csv의 레코드 수 : 1836
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_322000.csv의 레코드 수 : 644
# 중복 제거 후 output/naver_stock_articles_20대_이재명_322000.csv의 레코드 수 : 133
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_330350.csv의 레코드 수 : 882
# 중복 제거 후 output/naver_stock_articles_20대_이재명_330350.csv의 레코드 수 : 162
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_20대_이재명_336260.csv의 레코드 수 : 14813
# 중복 제거 후 output/naver_stock_articles_20대_이재명_336260.csv의 레코드 수 : 753
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_김동연_024940.csv의 레코드 수 : 3922
# 중복 제거 후 output/naver_stock_articles_21대_김동연_024940.csv의 레코드 수 : 380
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_김문수_010770.csv의 레코드 수 : 7810688
# 중복 제거 후 output/naver_stock_articles_21대_김문수_010770.csv의 레코드 수 : 17125
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_김문수_014160.csv의 레코드 수 : 870763
# 중복 제거 후 output/naver_stock_articles_21대_김문수_014160.csv의 레코드 수 : 4090
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_김문수_014710.csv의 레코드 수 : 1373
# 중복 제거 후 output/naver_stock_articles_21대_김문수_014710.csv의 레코드 수 : 208
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_김문수_024830.csv의 레코드 수 : 11308
# 중복 제거 후 output/naver_stock_articles_21대_김문수_024830.csv의 레코드 수 : 641
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_김문수_025750.csv의 레코드 수 : 4181
# 중복 제거 후 output/naver_stock_articles_21대_김문수_025750.csv의 레코드 수 : 377
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_김문수_090080.csv의 레코드 수 : 98617
# 중복 제거 후 output/naver_stock_articles_21대_김문수_090080.csv의 레코드 수 : 1924
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_김문수_109080.csv의 레코드 수 : 652
# 중복 제거 후 output/naver_stock_articles_21대_김문수_109080.csv의 레코드 수 : 135
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_안철수_004770.csv의 레코드 수 : 156581
# 중복 제거 후 output/naver_stock_articles_21대_안철수_004770.csv의 레코드 수 : 2435
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_안철수_013700.csv의 레코드 수 : 273
# 중복 제거 후 output/naver_stock_articles_21대_안철수_013700.csv의 레코드 수 : 78
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_안철수_053800.csv의 레코드 수 : 153561
# 중복 제거 후 output/naver_stock_articles_21대_안철수_053800.csv의 레코드 수 : 2439
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_오세훈_003780.csv의 레코드 수 : 4179
# 중복 제거 후 output/naver_stock_articles_21대_오세훈_003780.csv의 레코드 수 : 382
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_오세훈_051630.csv의 레코드 수 : 3886
# 중복 제거 후 output/naver_stock_articles_21대_오세훈_051630.csv의 레코드 수 : 373
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_이재명_000050.csv의 레코드 수 : 65762
# 중복 제거 후 output/naver_stock_articles_21대_이재명_000050.csv의 레코드 수 : 1563
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_이재명_035620.csv의 레코드 수 : 87
# 중복 제거 후 output/naver_stock_articles_21대_이재명_035620.csv의 레코드 수 : 37
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_이재명_042940.csv의 레코드 수 : 3364821
# 중복 제거 후 output/naver_stock_articles_21대_이재명_042940.csv의 레코드 수 : 11314
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_이재명_052400.csv의 레코드 수 : 4397646
# 중복 제거 후 output/naver_stock_articles_21대_이재명_052400.csv의 레코드 수 : 9316
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_이재명_053580.csv의 레코드 수 : 559688
# 중복 제거 후 output/naver_stock_articles_21대_이재명_053580.csv의 레코드 수 : 3511
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한덕수_008500.csv의 레코드 수 : 34544
# 중복 제거 후 output/naver_stock_articles_21대_한덕수_008500.csv의 레코드 수 : 1125
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한덕수_009410.csv의 레코드 수 : 812
# 중복 제거 후 output/naver_stock_articles_21대_한덕수_009410.csv의 레코드 수 : 164
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한덕수_009415.csv의 레코드 수 : 2949
# 중복 제거 후 output/naver_stock_articles_21대_한덕수_009415.csv의 레코드 수 : 313
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한덕수_020710.csv의 레코드 수 : 1354837
# 중복 제거 후 output/naver_stock_articles_21대_한덕수_020710.csv의 레코드 수 : 7095
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한덕수_289010.csv의 레코드 수 : 468275
# 중복 제거 후 output/naver_stock_articles_21대_한덕수_289010.csv의 레코드 수 : 4184
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한덕수_363280.csv의 레코드 수 : 1057
# 중복 제거 후 output/naver_stock_articles_21대_한덕수_363280.csv의 레코드 수 : 191
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한덕수_36328K.csv의 레코드 수 : 877
# 중복 제거 후 output/naver_stock_articles_21대_한덕수_36328K.csv의 레코드 수 : 160
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_004100.csv의 레코드 수 : 287838
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_004100.csv의 레코드 수 : 3246
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_014190.csv의 레코드 수 : 171
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_014190.csv의 레코드 수 : 65
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_014470.csv의 레코드 수 : 5756
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_014470.csv의 레코드 수 : 313
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_014530.csv의 레코드 수 : 286
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_014530.csv의 레코드 수 : 54
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_084695.csv의 레코드 수 : 238
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_084695.csv의 레코드 수 : 80
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_163730.csv의 레코드 수 : 24850
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_163730.csv의 레코드 수 : 651
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_173130.csv의 레코드 수 : 12220
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_173130.csv의 레코드 수 : 495
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_376930.csv의 레코드 수 : 3725
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_376930.csv의 레코드 수 : 260
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_한동훈_383930.csv의 레코드 수 : 7168
# 중복 제거 후 output/naver_stock_articles_21대_한동훈_383930.csv의 레코드 수 : 491
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
# 중복 제거 전 output/naver_stock_articles_21대_홍준표_039240.csv의 레코드 수 : 26547
# 중복 제거 후 output/naver_stock_articles_21대_홍준표_039240.csv의 레코드 수 : 972
# 전처리된 데이터가 csv, json 포멧으로 저장되었습니다.
#
#
# --------------------------------------------------
# 전처리된 모든 데이터가 cleaned_output 폴더에 파일 csv, json로 저장되었습니다.
# 중복제거 전 전체 데이터 레코드 수 : 39007926
# 중복제거 후 전체 데이터 레코드 수 : 177063
# 전체 데이터의 레코드 수 : 177063
